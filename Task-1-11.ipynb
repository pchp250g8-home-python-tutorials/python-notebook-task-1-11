# %% [markdown]
# При каких целых значениях n выражение (3 * n - 1) / (n + 2) является натуральным чиcлом?

# %%
from numpy import array
from sympy import pdiv
from sympy import apart
from sympy import divisors
from sympy.abc import n

print(pdiv(3 * n - 1, n + 2))
print(apart((3 * n - 1) / (n + 2)))
divs = array(divisors(7))
print(divs, -divs)

# %%
from sympy import solve
from sympy.abc import n
from sympy import Eq

ans = []
sol = sorted([solve(Eq(-7 / (n + 2), 1)), 
       solve(Eq(-7 / (n + 2), 7)), 
       solve(Eq(-7 / (n + 2), -1)), 
       solve(Eq(-7 / (n + 2), -7))])
for v in sol:
      n =  v.pop()
      if (3 - 7 / (n + 2) > 0):
             ans.append(n)
print(ans)

# %%
from sympy import solve
from sympy.abc import n
from sympy import Eq

ans = []
sol = sorted([solve(Eq(n + 2, 1)), 
              solve(Eq(n + 2, 7)), 
              solve(Eq(n + 2, -1)), 
              solve(Eq(n + 2, -7))])
for v in sol:
      n =  v.pop()
      if (3 - 7 / (n + 2) > 0):
             ans.append(n)
print(ans)
